# %% [markdown]
# <a href="https://colab.research.google.com/github/csmotherman/CSC302HW1/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **github username: csmotherman**

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file = '/content/drive/MyDrive/DATA/olympic_medals.csv'
data = pd.read_csv(file)

# %% [markdown]
# *Question 2a: Find the size of the data frame. How many rows, how many columns?*

# %%
data
# Out:
#      Gender              Event Location  Year Medal                   Name  \
# 0         M         10000M Men      Rio  2016     G          Mohamed FARAH
# 1         M         10000M Men      Rio  2016     S  Paul Kipngetich TANUI
# 2         M         10000M Men      Rio  2016     B           Tamirat TOLA
# 3         M         10000M Men  Beijing  2008     G        Kenenisa BEKELE
# 4         M         10000M Men  Beijing  2008     S         Sileshi SIHINE
# ...     ...                ...      ...   ...   ...                    ...
# 2389      W  Triple Jump Women   Athens  2004     S      Hrysopiyi DEVETZI
# 2390      W  Triple Jump Women   Athens  2004     B       Tatyana LEBEDEVA
# 2391      W  Triple Jump Women  Atlanta  1996     G         Inessa KRAVETS
# 2392      W  Triple Jump Women  Atlanta  1996     S        Inna LASOVSKAYA
# 2393      W  Triple Jump Women  Atlanta  1996     B       Sarka KASPARKOVA
#
#      Nationality    Result
# 0            GBR  25:05.17
# ...

# %% [markdown]
# From calling the object that we created, we can see the number of rows and columns at the bottom. **This dataset has 2394 rows and 8 columns**.

# %% [markdown]
# *Question 2b: Use the appropriate function to report the data types for all columns.*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2394 entries, 0 to 2393
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       2394 non-null   object
#  1   Event        2394 non-null   object
#  2   Location     2394 non-null   object
#  3   Year         2394 non-null   int64
#  4   Medal        2394 non-null   object
#  5   Name         2164 non-null   object
#  6   Nationality  2394 non-null   object
#  7   Result       2394 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 149.8+ KB

# %% [markdown]
# *Question 2c: Find how many unique cities matches were held at.*

# %%
unique_cities = data['Location'].unique()
len(unique_cities)
# Out:
# 23

# %% [markdown]
# **There are 23 unique cities that the matches were held at.**

# %% [markdown]
# *Question 2d: Find how many medals the USA team won in total.*

# %%
USA_mask = data['Nationality'] == 'USA'
USA_medals = data[USA_mask]
USA_medals
# Out:
#      Gender             Event   Location  Year Medal             Name  \
# 37        M        10000M Men     London  2012     S       Galen RUPP
# 51        M        10000M Men      Tokyo  1964     G      Billy MILLS
# 67        M        10000M Men  Stockholm  1912     S   Lewis TEWANIMA
# 70        M          100M Men        Rio  2016     S    Justin GATLIN
# 74        M          100M Men    Beijing  2008     B       Walter DIX
# ...     ...               ...        ...   ...   ...              ...
# 2326      W  Pole Vault Women    Beijing  2008     S    Jennifer SUHR
# 2328      W  Pole Vault Women     Sydney  2000     G    Stacy DRAGILA
# 2331      W  Pole Vault Women     London  2012     G    Jennifer SUHR
# 2337      W    Shot Put Women        Rio  2016     G  Michelle CARTER
# 2358      W    Shot Put Women       Rome  1960     B    Earlene BROWN
#
#      Nationality    Result
# 37           USA  27:30.90
# 51           USA   28:24.4
# 67           USA   32:06.6
# ...

# %% [markdown]
# By creating a mask where the Nationality is only "USA", we can get a list of how many medals that only the USA has won. After, we can look at the total number of rows in this new dataset. **The total number of medals that the USA won is 638.**

# %% [markdown]
# *Question 2e: Find the total number of medals for each Nationality.*

# %%
data.groupby(by = 'Nationality')['Medal'].count()
# Out:
# Nationality
# ALG      9
# ARG      4
# AUS     57
# AUT      4
# BAH     12
#       ...
# URS    131
# USA    638
# VEN      2
# YUG      1
# ZAM      1
# Name: Medal, Length: 97, dtype: int64
